# %% [markdown]
# # TensorFlow dan Tebak Gambar Bersama Komputer

# %% [markdown]
# ![title](bahan/image/markblogtensorflow.png)
# ![title](bahan/image/lombokdevmeetup.png)
# ![title](bahan/image/itec.png)

# %% [markdown]
# ## Intelligence
#
# Has been century questioning, but still intelligence is cannot defined by simple word.<br/>
#
# ### Einstein said, "The true sign of intelligence is not knowledge but imagination13." <br/>
# ### Socrates said, "I know that I am intelligent, because I know that I know nothing."
#
# ### Intelligence has been defined in many different ways including as one's capacity for logic, understanding, self-awareness, learning, emotional knowledge, planning, creativity, and problem solving. (Wikipedia)
#
# ### Intelligence is defined as general cognitive problem-solving skills. A mental ability involved in reasoning, perceiving relationships and analogies, calculating, learning quickly… etc. Earlier it was believed that there was one underlying general factor at the intelligence base (the g-factor), but later psychologists maintained that it is more complicated and could not be determined by such a simplistic method.(http://www.brainmetrix.com/intelligence-definition/)
#
#
# ## Kecerdasan dan Otak
# ![title](bahan/image/cortex-comparison_med.jpeg)
#
# #### Otak Paling Moderen pada Manusia adalak Otak Bahasa dan Visual
# Dan Dia mengajarkan kepada Adam nama-nama itu semuanya, kemudian Dia mengemukakan mereka itu kepada para malaikat lalu Dia berfirman: " Beritahukanlah kepada-Ku nama-nama mereka ini jika kamu memang benar.” Mereka berkata: “Mahasuci Engkau, kami tidak memiliki pengetahuan kecuali apa yang telah Engkau ajarkan kepada kami, sesungguhnya Engkau benar-benar Maha Mengetahui, Mahabijaksana.” (Al-Baqarah [2]:32-33).
#
# ### Ilmuan di bidang neuro science menemukan bahwa bagian otak yang paling moderen adalah otak yang berfungsi sebagai pengolah bahasa, pengolah visual dan pengolah suara.

# %% [markdown]
# ## Artificial Intelligence
#
# ![title](bahan/image/ext.jpg)
#
# #### Apa itu artificial Intelligence
# Artificial Intelligence (which I'll refer to hereafter by its nickname, “AI”) is the subfield of Computer Science devoted to developing programs that enable computers to display behavior that can (broadly) be characterized as intelligent.Aug 27, 2003
# https://plato.stanford.edu/entries/logic-ai/

# %% [markdown]
# #### Produk Artificial Intelligence

# %% [markdown]
# <video controls src="bahan/video/video1.mp4" width="640px"/>

# %% [markdown]
# ### Artificial Neural Network
#
# ![title](bahan/image/Neural-network.jpg)
# <center>Saraf Asli Manusia</center>
# <br/>
#
# ![title](bahan/image/neuron.png)
# <center>Saraf Asli Manusia</center>
# <br/>
#
#
# ![title](bahan/image/neural-network.png)
# <center>Regression Neural Network</center>
# <br/>
#
# ![title](bahan/image/neural_net.jpeg)
# <center>Classification Neural Network</center>
# <br/>
#
#
# ![title](bahan/image/1-5egrX--WuyrLA7gBEXdg5A.png)

# %% [markdown]
# ## Apaan sih TensorFlow?
#
# TensorFlow is an open source software library for numerical computation using data flow graphs. The graph nodes represent mathematical operations, while the graph edges represent the multidimensional data arrays (tensors) that flow between them. ... TensorFlow also includes TensorBoard, a data visualization toolkit.
#
# TensorFlow was originally developed by researchers and engineers working on the Google Brain Team within Google's Machine Intelligence research organization for the purposes of conducting machine learning and deep neural networks research, but the system is general enough to be applicable in a wide variety of other domains as well.
#
# https://github.com/tensorflow/tensorflow

# %% [markdown]
# ## Emang Bisa Komputer Tebak Gambar?
#
# Image Classifier <br>
# MobileNet <br/>
# Inception <br/>

# %% [markdown]
# ## Convolutional Neural Network
# ![title](bahan/image/mylenet.png)

# %% [markdown]
# ## Code Time!
# ### Tebak Gambar 1

# %%
from IPython.display import Image
Image(filename='tf_files/training_images/daisy/3475870145_685a19116d.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/training_images/daisy/3475870145_685a19116d.jpg
# Out:
# daisy 0.775
# dandelion 0.183479
# tulips 0.0372413
# roses 0.00391893
# sunflowers 0.000280229

# %% [markdown]
# ## Training Dulu Broh!
# Si Acer masih belum yakin 100% kalau ini bunga daisy... Di latih lagi liat gambar yang sudah disediakan di tf_files/training_images.... Mulai latihan yaaa...

# %%
# !python scripts/retrain.py \
  --bottleneck_dir=tf_files/bottlenecks \
  --how_many_training_steps=500 \
  --model_dir=tf_files/models/ \
  --summaries_dir=tf_files/training_summaries/mobilenet_0.50_224 \
  --output_graph=tf_files/retrained_graph.pb \
  --output_labels=tf_files/retrained_labels.txt \
  --architecture=mobilenet_0.50_224 \
  --image_dir=tf_files/training_images
# Out:
# INFO:tensorflow:Looking for images in 'sunflowers'
# INFO:tensorflow:Looking for images in 'wanita'
# INFO:tensorflow:Looking for images in 'roses'
# INFO:tensorflow:Looking for images in 'pria'
# INFO:tensorflow:Looking for images in ''askar'
# INFO:tensorflow:Looking for images in 'tulips'
# INFO:tensorflow:Looking for images in 'fandi'
# INFO:tensorflow:Looking for images in 'daisy'
# INFO:tensorflow:Looking for images in 'dandelion'
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/'askar/P_20161231_184428.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/'askar/P_20161231_185614.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/'askar/P_20161231_185618.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/'askar/P_20161027_164410.jpg_mobilenet_0.50_224.txt
# ...

# %% [markdown]
# ## Ayo Tebak Gambar ini Broh!

# %%
Image(filename='tf_files/training_images/daisy/3475870145_685a19116d.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/training_images/daisy/3475870145_685a19116d.jpg
# Out:
# daisy 0.791943
# dandelion 0.140306
# tulips 0.0573756
# roses 0.0097175
# sunflowers 0.000516397

# %% [markdown]
# ## Tebak Gambar 2

# %%
Image(filename='tf_files/testing_images/whois2.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/testing_images/whois2.jpg
# Out:
# fandi 0.878293
# pria 0.0379608
#  askar 0.0376729
# wanita 0.0290894
# sunflowers 0.00720799

# %% [markdown]
# ## Tebak Gambar 3

# %%
Image(filename='tf_files/testing_images/whois3.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/testing_images/whois3.jpg
# Out:
# pria 0.870448
# fandi 0.121637
# daisy 0.00470104
# roses 0.00178358
# sunflowers 0.000523642

# %% [markdown]
# ## Tebak Gambar 4

# %%
Image(filename='tf_files/testing_images/whois4.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/testing_images/whois4.jpg
# Out:
# wanita 0.942687
# roses 0.0517595
# tulips 0.00213155
#  askar 0.00162268
# sunflowers 0.000743797

# %% [markdown]
# ## Tebak Gambar 5

# %%
Image(filename='tf_files/testing_images/whatis1.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/testing_images/whatis1.jpg
# Out:
# daisy 0.91368
# tulips 0.069821
# roses 0.0160409
# sunflowers 0.000317172
# wanita 6.44723e-05

# %% [markdown]
# ## Tebak Gambar 6

# %%
Image(filename='tf_files/testing_images/whatis2.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/testing_images/whatis2.jpg
# Out:
# tulips 0.502141
# roses 0.415166
# wanita 0.0509878
# fandi 0.0256702
# pria 0.00537815

# %% [markdown]
# ## Tebak Gambar 7

# %%
Image(filename='tf_files/testing_images/whois10.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/testing_images/whois10.jpg
# Out:
#  askar 0.871517
# pria 0.038548
# fandi 0.0357237
# sunflowers 0.0164515
# daisy 0.0130993

# %% [markdown]
# ## Tebak Gambar 8

# %%
Image(filename='tf_files/testing_images/whois11.jpg')

# %%
# !python scripts/label_image.py \
  --graph=tf_files/retrained_graph.pb  \
  --image=tf_files/testing_images/whois11.jpg
# Out:
#  askar 0.997719
# fandi 0.000864222
# daisy 0.000397079
# tulips 0.000345146
# wanita 0.000327727

# %% [markdown]
# ## Sumber Referensi
# https://blog.rescale.com/wp-content/uploads/2017/02/markblogtensorflow.png <br/>
# http://deeplearning.net/tutorial/_images/mylenet.png <br/>
# https://blog.rescale.com/wp-content/uploads/2017/02/markblogtensorflow.png <br/>
#
# https://media.licdn.com/media-proxy/ext?w=800&h=800&hash=EUkAC%2FORLPmOoaNptXccxoY6iO4%3D&ora=1%2CaFBCTXdkRmpGL2lvQUFBPQ%2CxAVta5g-0R6nlh8Tw1It6a2FowGz60oISJLOTW3hGTrbi6DxERaYCLauCMPQ1R1ECV1w4X5GAbPVQlngbNnJKvaLG4EP__KhWuSCbyoPOBUbn1hWwOU8bDQutsaJMtn5TRljg8JfIyWtNA <br/>
#
# http://www.texample.net/media/tikz/examples/PNG/neural-network.png<br/>
#
# http://cs231n.github.io/assets/nn1/neural_net.jpeg <br/>
